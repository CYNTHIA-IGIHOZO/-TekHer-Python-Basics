# %% [markdown]
# # Practical_7: Matplotlib

# %% [markdown]
# ---
#
# ### Exercise 1:
# Create a simple line plot for `y = x` for `x` values ranging from 0 to 10.

# %%
# Exercise 1
import matplotlib.pyplot as plt

x = list(range(0, 11))
y = x

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line plot of y = x')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 2:
# Plot `y = x^2` using Matplotlib for `x` values between -10 and 10.

# %%
# Exercise 2
import numpy as np
import numpy as np

X = np.arange(-10, 11)
y = X ** 2              

plt.plot(X, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x^2')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 3:
# Create a scatter plot with 50 random points where x and y values are between 0 and 10.

# %%
# Exercise 3
x = np.random.uniform(0, 10, 50)
y = np.random.uniform(0, 10, 50)

plt.scatter(x, y)
plt.title("Scatter Plot of 50 Random Points")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 4:
# Plot a sine wave using Matplotlib for `x` values between 0 and 2π.

# %%
# Exercise 4
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.figure()
plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 5:
# Create a bar chart for the following data: `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
# Exercise 5
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
plt.figure()
plt.bar(categories, values)
plt.title("Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 6:
# Create a histogram of 1000 random numbers generated from a normal distribution.

# %%
# Exercise 6
data = np.random.randn(1000)
plt.figure()
plt.hist(data, bins=30, edgecolor='black')
plt.title("Histogram of Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 7:
# Plot two line plots on the same graph: `y1 = x^2` and `y2 = x^3` for `x` ranging from 0 to 10.

# %%
# Exercise 7
x = np.linspace(0, 10, 100)
y1 = x ** 2
y2 = x ** 3
plt.figure()
plt.plot(x, y1, label='x^2')
plt.plot(x, y2, label='x^3')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 8:
# Add titles, axis labels, and a legend to the plot in Exercise 7.

# %%
# Exercise 8
plt.figure()
plt.plot(x, y1, label='x^2')
plt.plot(x, y2, label='x^3')
plt.title("Line Plots of x^2 and x^3")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 9:
# Create a subplot with 2 rows and 1 column. Plot `y1 = x^2` in the first subplot and `y2 = x^3` in the second.

# %%
# Exercise 9
fig, axs = plt.subplots(2, 1, figsize=(6, 8))
axs[0].plot(x, y1, 'b')
axs[0].set_title("x^2")
axs[1].plot(x, y2, 'r')
axs[1].set_title("x^3")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 10:
# Use a different color and linestyle for each line in a plot of three functions: `y1 = x`, `y2 = x^2`, and `y3 = x^3`.

# %%
# Exercise 10
y3 = x
plt.figure()
plt.plot(x, y3, 'g--', label='x')
plt.plot(x, y1, 'b-.', label='x^2')
plt.plot(x, y2, 'r:', label='x^3')
plt.title("Different Functions with Styles")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 11:
# Create a pie chart with 5 segments labeled A, B, C, D, and E, with values `[25, 35, 20, 15, 5]`.

# %%
# Exercise 11
labels = ['A', 'B', 'C', 'D', 'E']
sizes = [25, 35, 20, 15, 5]
plt.figure()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Pie Chart")
plt.axis('equal')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 12:
# Create a horizontal bar chart with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`.

# %%
# Exercise 12
plt.figure()
plt.barh(categories, values, color='purple')
plt.title("Horizontal Bar Chart")
plt.xlabel("Values")
plt.ylabel("Categories")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 13:
# Change the figure size of a line plot to 10x6 inches.

# %%
# Exercise 13
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.title("Figure Size 10x6")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 14:
# Plot a filled area under the curve of `y = x^2` for `x` ranging from 0 to 10.

# %%
# Exercise 14
x = np.linspace(0, 10, 100)
y = x**2
plt.figure()
plt.fill_between(x, y, color='skyblue', alpha=0.5)
plt.plot(x, y, color='blue')
plt.title("Filled Area Under x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 15:
# Change the style of the plot to `ggplot` and replot the sine wave from Exercise 4.

# %%
# Exercise 15
plt.style.use('ggplot')
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.figure()
plt.plot(x, y)
plt.title("Sine Wave (ggplot style)")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 16:
# Create a stacked bar chart for the following data: `Group A = [3, 5, 7]`, `Group B = [2, 6, 4]`, and `categories = ['X', 'Y', 'Z']`.

# %%
# Exercise 16
group_a = [3, 5, 7]
group_b = [2, 6, 4]
categories = ['X', 'Y', 'Z']
x = np.arange(len(categories))
plt.figure()
plt.bar(x, group_a, label='Group A')
plt.bar(x, group_b, bottom=group_a, label='Group B')
plt.xticks(x, categories)
plt.title("Stacked Bar Chart")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 17:
# Create a plot with multiple subplots in a 2x2 grid. Plot `y1 = x`, `y2 = x^2`, `y3 = x^3`, and `y4 = x^4`.

# %%
# Exercise 17
x = np.linspace(0, 10, 100)
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
axs[0, 0].plot(x, x)
axs[0, 0].set_title("y = x")
axs[0, 1].plot(x, x**2)
axs[0, 1].set_title("y = x^2")
axs[1, 0].plot(x, x**3)
axs[1, 0].set_title("y = x^3")
axs[1, 1].plot(x, x**4)
axs[1, 1].set_title("y = x^4")
for ax in axs.flat:
    ax.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 18:
# Create a heatmap using a 2D array of random values with shape (5, 5).

# %%
# Exercise 18
data = np.random.rand(5, 5)
plt.figure()
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title("Heatmap")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 19:
# Add error bars to a bar plot with `categories = ['A', 'B', 'C', 'D']` and `values = [3, 7, 5, 9]`, assuming the error is 1 for each value.

# %%
# Exercise 19
categories = ['A', 'B', 'C', 'D']
values = [3, 7, 5, 9]
errors = [1, 1, 1, 1]
plt.figure()
plt.bar(categories, values, yerr=errors, capsize=5, color='lightblue', edgecolor='black')
plt.title("Bar Plot with Error Bars")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 20:
# Plot a sine wave using a dashed line and a cosine wave using a solid line on the same plot.

# %%
# Exercise 20
x = np.linspace(0, 2 * np.pi, 100)
plt.figure()
plt.plot(x, np.sin(x), 'r--', label='sin(x)')
plt.plot(x, np.cos(x), 'b-', label='cos(x)')
plt.title("Sine (dashed) and Cosine (solid)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 21:
# Plot a contour plot for the function `z = sin(x) + cos(y)` over a grid of `x` and `y` values ranging from -5 to 5.

# %%
# Exercise 21
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) + np.cos(Y)
plt.figure()
cp = plt.contourf(X, Y, Z, cmap='viridis')
plt.colorbar(cp)
plt.title("Contour Plot of sin(x) + cos(y)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 22:
# Create a box plot for a dataset generated with 100 random numbers from a normal distribution.

# %%
# Exercise 22
data = np.random.randn(100)
plt.figure()
plt.boxplot(data)
plt.title("Box Plot of Normally Distributed Data")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 23:
# Create a scatter plot with a color map applied to the points, where the color represents the value of the points.

# %%
# Exercise 23
x = np.random.rand(100)
y = np.random.rand(100)
colors = x + y

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar(label='Color Intensity')
plt.title('Scatter Plot with Colormap')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 24:
# Use Matplotlib to display an image from a file.

# %%
# Exercise 24
import matplotlib.image as mpimg
img = mpimg.imread('steps_comparison.png')
plt.imshow(img)
plt.axis('off')
plt.title('Image Display')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 25:
# Create a plot with logarithmic scaling on both axes.

# %%
# Exercise 25
x = np.logspace(0.1, 2, 100)
y = x ** 2

plt.loglog(x, y)
plt.title('Log-Log Plot')
plt.xlabel('X (log scale)')
plt.ylabel('Y (log scale)')
plt.grid(True, which='both')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 26:
# Create a 3D plot of the function `z = x^2 + y^2` over a grid of `x` and `y` values.

# %%
# Exercise 26
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

x = y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = x**2 + y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')
plt.title('3D Plot of z = x² + y²')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 27:
# Create a radar chart with 5 variables and random values between 0 and 1.

# %%
# Exercise 27
labels = ['A', 'B', 'C', 'D', 'E']
values = np.random.rand(5)
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
values = np.concatenate((values, [values[0]]))
angles += angles[:1]

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(angles, values, marker='o')
ax.fill(angles, values, alpha=0.25)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title('Radar Chart')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 28:
# Create a violin plot to show the distribution of a dataset generated with 1000 random numbers from a normal distribution.

# %%
# Exercise 28
data = np.random.normal(0, 1, 1000)
plt.violinplot(data)
plt.title('Violin Plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 29:
# Create a bar chart with different colors for each bar.

# %%
# Exercise 29
x = np.arange(5)
y = np.random.randint(1, 10, size=5)
colors = ['red', 'green', 'blue', 'purple', 'orange']

plt.bar(x, y, color=colors)
plt.title('Bar Chart with Different Colors')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 30:
# Create a stem plot for the function `y = sin(x)` for `x` values between 0 and 2π.

# %%
# Exercise 30
x = np.linspace(0, 2 * np.pi, 50)
y = np.sin(x)

plt.stem(x, y)
plt.title('Stem Plot of sin(x)')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 31:
# Create a scatter plot with markers of different sizes.

# %%
# Exercise 31
x = np.random.rand(100)
y = np.random.rand(100)
sizes = 100 * np.random.rand(100)

plt.scatter(x, y, s=sizes, alpha=0.6)
plt.title('Scatter Plot with Variable Sizes')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 32:
# Plot a cumulative histogram of 1000 random numbers generated from a uniform distribution.

# %%
# Exercise 32
data = np.random.rand(1000)
plt.hist(data, bins=30, cumulative=True)
plt.title('Cumulative Histogram')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 33:
# Create a pie chart with custom colors for each segment.

# %%
# Exercise 33
sizes = [25, 35, 20, 20]
labels = ['A', 'B', 'C', 'D']
colors = ['skyblue', 'salmon', 'limegreen', 'gold']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Custom Colored Pie Chart')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 34:
# Create a plot with twin y-axes where one axis represents `y = x` and the other represents `y = x^2`.

# %%
# Exercise 34
x = np.linspace(0, 10, 100)
y1 = x
y2 = x**2

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.plot(x, y1, 'g-', label='y = x')
ax2.plot(x, y2, 'b-', label='y = x^2')

ax1.set_ylabel('y = x', color='g')
ax2.set_ylabel('y = x^2', color='b')
plt.title('Twin Y-Axis Plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 35:
# Plot a density plot of 1000 random values from a normal distribution.

# %%
# Exercise 35
import seaborn as sns
data = np.random.normal(0, 1, 1000)
sns.kdeplot(data)
plt.title('Density Plot')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ---
#
# ### Exercise 36:
# Create a histogram and add a kernel density estimate (KDE) to the plot.

# %%
# Exercise 36
data = np.random.normal(size=1000)
sns.histplot(data, kde=True)
plt.title('Histogram with KDE')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ---
#
# ### Exercise 37:
# Add gridlines to a line plot and change the color and linestyle of the grid.

# %%
# Exercise 37
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.grid(True, color='gray', linestyle='--')
plt.title('Line Plot with Custom Grid')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 38:
# Create a bar chart with annotations showing the height of each bar above the bar.

# %%
# Exercise 38
x = np.arange(5)
y = np.random.randint(1, 10, size=5)

plt.bar(x, y)
for i, val in enumerate(y):
    plt.text(i, val + 0.2, str(val), ha='center')
plt.title('Bar Chart with Annotations')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 39:
# Create a filled contour plot for the function `z = x^2 + y^2` over a grid of `x` and `y` values.

# %%
# Exercise 39
x = y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = x**2 + y**2

plt.contourf(x, y, z, cmap='viridis')
plt.colorbar()
plt.title('Filled Contour Plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 40:
# Create a stacked area plot using three random datasets.

# %%
# Exercise 40
x = np.arange(10)
y1 = np.random.rand(10)
y2 = np.random.rand(10)
y3 = np.random.rand(10)

plt.stackplot(x, y1, y2, y3, labels=['A', 'B', 'C'])
plt.legend()
plt.title('Stacked Area Plot')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 41:
# Create a bar chart with error bars, where the error values are proportional to the bar values.

# %%
# Exercise 41
x = np.arange(5)
y = np.random.rand(5) * 10
errors = y * 0.1  # 10% error

plt.bar(x, y, yerr=errors, capsize=5)
plt.title('Bar Chart with Error Bars')
plt.show()

# %% [markdown]
# ---
#
# ### Exercise 42:
# Create a wind rose chart using random wind direction and speed data.

# %%
# Exercise 42
directions = np.random.randint(0, 360, 100)
speeds = np.random.rand(100) * 10
plt.figure()
plt.hist(directions, bins=16, weights=speeds, color='skyblue', edgecolor='black')
plt.title("Wind Rose (Simulated)")
# Out:
# Text(0.5, 1.0, 'Wind Rose (Simulated)')

# %% [markdown]
# ---
#
# ### Exercise 43:
# Plot a cumulative frequency curve for a dataset of 100 random numbers.

# %%
# Exercise 43
data43 = np.random.rand(100)
data43_sorted = np.sort(data43)
cum_freq = np.arange(1, len(data43_sorted) + 1) / len(data43_sorted)
plt.figure()
plt.plot(data43_sorted, cum_freq, marker='.')
plt.title("Cumulative Frequency")
# Out:
# Text(0.5, 1.0, 'Cumulative Frequency')

# %% [markdown]
# ---
#
# ### Exercise 44:
# Create a waterfall chart using Matplotlib to show the changes in a sequence of values.

# %%
# Exercise 44
data44 = [100, -20, 30, -10, 50]
labels44 = ['Start', 'Drop1', 'Gain1', 'Drop2', 'Final']
cum_values = np.cumsum([0] + data44[:-1])
colors44 = ['green' if val >= 0 else 'red' for val in data44]
plt.figure()
for i in range(len(data44)):
    plt.bar(labels44[i], data44[i], bottom=cum_values[i], color=colors44[i])
plt.title("Waterfall Chart")
# Out:
# Text(0.5, 1.0, 'Waterfall Chart')

# %% [markdown]
# ---
#
# ### Exercise 45:
# Use the `imshow` function to display a 10x10 matrix of random values as an image.

# %%
# Exercise 45
data45 = [np.random.randn(100) for _ in range(4)]
plt.figure()
plt.boxplot(data45, labels=['A', 'B', 'C', 'D'])
plt.title("Multiple Boxplots")
# Out:
# Text(0.5, 1.0, 'Multiple Boxplots')

# %% [markdown]
# ---
#
# ### Exercise 46:
# Create a line plot with different markers for each point.

# %%
# Exercise 46
categories46 = ['A', 'B', 'C', 'D']
values46 = [3, 7, 5, 9]
plt.figure()
plt.barh(categories46, values46, color='teal')
plt.title("Horizontal Bar Chart")
# Out:
# Text(0.5, 1.0, 'Horizontal Bar Chart')

# %% [markdown]
# ---
#
# ### Exercise 47:
# Create a time series plot using Matplotlib and plot random data over a range of dates.

# %%
# Exercise 47
x47 = np.random.randn(1000)
y47 = np.random.randn(1000)
plt.figure()
plt.hexbin(x47, y47, gridsize=30, cmap='inferno')
plt.colorbar()
plt.title("Hexbin Plot")
# Out:
# Text(0.5, 1.0, 'Hexbin Plot')

# %% [markdown]
# ---
#
# ### Exercise 48:
# Create a bar chart with bars colored by category.

# %%
# Exercise 48
x48 = np.linspace(0, 10, 50)
y48 = np.sin(x48)
plt.figure()
plt.plot(x48, y48)
plt.annotate('Peak', xy=(np.pi/2, 1), xytext=(2, 1.5),
             arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.title("Annotated Line Plot")
# Out:
# Text(0.5, 1.0, 'Annotated Line Plot')

# %% [markdown]
# ---
#
# ### Exercise 49:
# Create a radar chart to visualize the strengths of five different attributes.

# %%
# Exercise 49
x49 = np.random.rand(50)
y49 = np.random.rand(50)
sizes49 = np.random.rand(50) * 1000
colors49 = np.random.rand(50)
plt.figure()
plt.scatter(x49, y49, s=sizes49, c=colors49, alpha=0.6, cmap='Spectral')
plt.title("Bubble Chart")
# Out:
# Text(0.5, 1.0, 'Bubble Chart')

# %% [markdown]
# ---
#
# ### Exercise 50:
# Create a 3D scatter plot with random values for x, y, and z.

# %%
# Exercise 50
import pandas as pd

dates50 = pd.date_range(start="2023-01-01", periods=100)
values50 = np.cumsum(np.random.randn(100))
plt.figure()
plt.plot(dates50, values50)
plt.title("Time Series Plot")
plt.xlabel("Date")
plt.ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# ---
