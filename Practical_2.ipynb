# %% [markdown]
# # Practical_2: String and files

# %% [markdown]
# ---
#
# ### Exercise 1:
# Create a string variable `text` and assign it the value `"Python is amazing!"`.
#
# ```python
# # Exercise 1
# ```
#
# ---
#
# ### Exercise 2:
# Find the length of the string `"Hello, World!"` and store it in a variable `length`.
#
# ```python
# # Exercise 2
# ```
#
# ---
#
# ### Exercise 3:
# Convert the string `"python programming"` to uppercase and store it in a variable `upper_text`.
#
# ```python
# # Exercise 3
# ```
#
# ---
#
# ### Exercise 4:
# Extract the first 5 characters from the string `"Artificial Intelligence"`.
#
# ```python
# # Exercise 4
# ```
#
# ---
#
# ### Exercise 5:
# Concatenate the strings `"Hello"` and `"World"` with a space in between.
#
# ```python
# # Exercise 5
# ```
#
# ---
#
# ### Exercise 6:
# Replace the word `"dog"` with `"cat"` in the string `"The quick brown dog jumps over the lazy dog."`.
#
# ```python
# # Exercise 6
# ```
#
# ---
#
# ### Exercise 7:
# Split the string `"apple,banana,orange"` by commas and store the result in a list `fruits_list`.
#
# ```python
# # Exercise 7
# ```
#
# ---
#
# ### Exercise 8:
# Use string formatting to create the sentence `"My name is Alice and I am 25 years old."`, where the name and age are variables.
#
# ```python
# # Exercise 8
# ```
#
# ---
#
# ### Exercise 9:
# Check if the string `"python"` is present in the sentence `"I love python programming"`.
#
# ```python
# # Exercise 9
# ```
#
# ---
#
# ### Exercise 10:
# Count the number of occurrences of the letter `"e"` in the string `"Elephant is an elegant animal"`.
#
# ```python
# # Exercise 10
# ```
#
# ---
#
# ### Exercise 11:
# Remove any leading and trailing spaces from the string `"   Data Science   "`.
#
# ```python
# # Exercise 11
# ```
#
# ---
#
# ### Exercise 12:
# Convert the string `"100"` into an integer and store it in a variable `int_value`.
#
# ```python
# # Exercise 12
# ```
#
# ---
#
# ### Exercise 13:
# Extract the substring `"pro"` from the string `"programming"`.
#
# ```python
# # Exercise 13
# ```
#
# ---
#
# ### Exercise 14:
# Check if the string `"data"` starts with `"da"` and ends with `"ta"`.
#
# ```python
# # Exercise 14
# ```
#
# ---
#
# ### Exercise 15:
# Reverse the string `"machine learning"` and store the result in `reversed_text`.
#
# ```python
# # Exercise 15
# ```
#
# ---
#
# ### Exercise 16:
# Convert the first letter of each word in the string `"machine learning is fun"` to uppercase.
#
# ```python
# # Exercise 16
# ```
#
# ---
#
# ### Exercise 17:
# Create a multiline string representing a poem and store it in a variable `poem`.
#
# ```python
# # Exercise 17
# ```
#
# ---
#
# ### Exercise 18:
# Write a string to a file named `"output.txt"`.
#
# ```python
# # Exercise 18
# ```
#
# ---
#
# ### Exercise 19:
# Read the contents of a file named `"data.txt"` and print it line by line.
#
# ```python
# # Exercise 19
# ```
#
# ---
#
# ### Exercise 20:
# Check if a file `"example.txt"` exists before opening it.
#
# ```python
# # Exercise 20
# ```
#
# ---
#
# ### Exercise 21:
# Append a new line `"This is a new line"` to an existing file `"notes.txt"`.
#
# ```python
# # Exercise 21
# ```
#
# ---
#
# ### Exercise 22:
# Read the contents of a file `"log.txt"` and store each line in a list `log_lines`.
#
# ```python
# # Exercise 22
# ```
#
# ---
#
# ### Exercise 23:
# Create a new file `"report.txt"` and write the string `"Data analysis report"` to it.
#
# ```python
# # Exercise 23
# ```
#
# ---
#
# ### Exercise 24:
# Replace the word `"error"` with `"issue"` in a file `"log.txt"`.
#
# ```python
# # Exercise 24
# ```
#
# ---
#
# ### Exercise 25:
# Count the number of words in a text file `"document.txt"`.
#
# ```python
# # Exercise 25
# ```
#
# ---
#
# ### Exercise 26:
# Write a Python script that reads a file `"essay.txt"` and prints the total number of lines, words, and characters.
#
# ```python
# # Exercise 26
# ```
#
# ---
#
# ### Exercise 27:
# Copy the contents of one file `"source.txt"` to another file `"destination.txt"`.
#
# ```python
# # Exercise 27
# ```
#
# ---
#
# ### Exercise 28:
# Write a Python function that takes a filename as input and returns the number of lines in the file.
#
# ```python
# # Exercise 28
# ```
#
# ---
#
# ### Exercise 29:
# Extract all the words from a text file `"article.txt"` that contain more than 5 characters.
#
# ```python
# # Exercise 29
# ```
#
# ---
#
# ### Exercise 30:
# Convert the contents of a file `"notes.txt"` to uppercase and save the result in another file `"uppercase_notes.txt"`.
#
# ```python
# # Exercise 30
# ```
#
# ---
#
# ### Exercise 31:
# Write a Python script that reads a file and removes all empty lines.
#
# ```python
# # Exercise 31
# ```
#
# ---
#
# ### Exercise 32:
# Open a file `"config.txt"` in both read and write mode.
#
# ```python
# # Exercise 32
# ```
#
# ---
#
# ### Exercise 33:
# Write a Python function that reads a file and prints the longest line in the file.
#
# ```python
# # Exercise 33
# ```
#
# ---
#
# ### Exercise 34:
# Write a Python script to count the frequency of each letter in a text file `"message.txt"`.
#
# ```python
# # Exercise 34
# ```
#
# ---
#
# ### Exercise 35:
# Write a Python script that reads a file and prints the total number of characters, excluding spaces.
#
# ```python
# # Exercise 35
# ```
#
# ---
#
# ### Exercise 36:
# Create a Python script to check whether a file is empty or not.
#
# ```python
# # Exercise 36
# ```
#
# ---
#
# ### Exercise 37:
# Write a Python function that reads a file and removes all punctuation marks from the text.
#
# ```python
# # Exercise 37
# ```
#
# ---
#
# ### Exercise 38:
# Create a Python function that writes a list of strings to a file, each string on a new line.
#
# ```python
# # Exercise 38
# ```
#
# ---
#
# ### Exercise 39:
# Write a Python script to count the number of lines that start with a specific letter (e.g., "A") in a text file.
#
# ```python
# # Exercise 39
# ```
#
# ---
#
# ### Exercise 40:
# Write a Python function that takes a string as input and writes it to a file `"output.txt"` in reverse order.
#
# ```python
# # Exercise 40
# ```
#
# ---
#
# ### Exercise 41:
# Write a Python script that reads a file and prints all the lines that contain the word `"Python"`.
#
# ```python
# # Exercise 41
# ```
#
# ---
#
# ### Exercise 42:
# Write a Python script that opens a file and removes all numeric digits from the file's content.
#
# ```python
# # Exercise 42
# ```
#
# ---
#
# ### Exercise 43:
# Write a Python script to find the most frequent word in a text file `"book.txt"`.
#
# ```python
# # Exercise 43
# ```
#
# ---
#
# ### Exercise 44:
# Write a Python script that reads a file and prints all the lines that contain exactly 5 words.
#
# ```python
# # Exercise 44
# ```
#
# ---
#
# ### Exercise 45:
# Write a Python script to read a file and print the first and last line of the file.
#
# ```python
# # Exercise 45
# ```
#
# ---
#
# ### Exercise 46:
# Write a Python script that checks if a file `"students.txt"` is writable.
#
# ```python
# # Exercise 46
# ```
#
# ---
#
# ### Exercise 47:
# Create a Python function that opens a file and returns the number of unique words in the file.
#
# ```python
# # Exercise 47
# ```
#
# ---
#
# ### Exercise 48:
# Write a Python script that reads a file and prints all lines in reverse order.
#
# ```python
# # Exercise 48
# ```
#
# ---
#
# ### Exercise 49:
# Write a Python function that reads a file and returns the most common letter in the text.
#
# ```python
# # Exercise 49
# ```
#
# ---
#
# ### Exercise 50:
# Write a Python script that reads a file and replaces every occurrence of `"Python"` with `"Java"`.
#
# ```python
# # Exercise 50
# ```
#
# ---

# %%
# Exercise 1
text="Python is amazing!"
text

# Exercise 2
length= "Hello, World!"
print(len(length))

# Exercise 3
upper_text = "python programming"
print(upper_text.upper())

# Exercise 4
Extract = "Artificial Intelligence"
print(Extract[:5])

# Exercise 5
Concatenate="Hello"+' '+"World"
print(Concatenate)

# Exercise 6
replace="The quick brown dog jumps over the lazy dog."
print(replace.replace("dog","cat"))

# Exercise 7
fruits_list="apple,banana,orange"
print(fruits_list.split(","))

# Exercise 8
name='igihozo'
age=26
infor="My name is {} and I am {} years old.".format(name, age)
print(infor)

# Exercise 9
check="I love python programming"
print("python" in check)

# Exercise 10
count="Elephant is an elegant animal"
print(count.count('e'))
# Out:
# 13
# PYTHON PROGRAMMING
# Artif
# Hello World
# The quick brown cat jumps over the lazy cat.
# ['apple', 'banana', 'orange']
# My name is igihozo and I am 26 years old.
# True
# 3

# %%
# Exercise 11
rem="   Data Science   "
print(rem.strip())

# Exercise 12
int_value='100'
int_value=int(int_value)
print(type(int_value))

# Exercise 13
extract="programming"
print(extract[:3])

# Exercise 14
Check="data"
print(Check.startswith('da'), Check.endswith('ta'))

# Exercise 15
reversed_text = "machine learning"
reversed_text = reversed_text[::-1]
print(reversed_text)

# Exercise 16
convert="machine learning is fun"
print(convert.title())

# Exercise 17
poem = """Roses are red,
Violets are blue,
Python is fun,
And so are you."""
print(poem)

# Exercise 18
with open('output.txt', 'w') as file:
    file.write("""Roses are red,
Violets are blue,
Python is fun,
And so are you.""")

# Exercise 19
with open("data.txt",'r') as file:
    contents=file.read()
    print(contents)
    file.close()

# Exercise 20
import os 
if os.path.exists('example.txt'):
    
    with open('example.txt', 'r') as file:
        show=file.read()
        print(show)
else:
    print('The file does not exist.')
 file.close()
# Out:
# Data Science

# %%
# Exercise 21
with open('notes.txt', 'a') as file:
     file.write("\nThis is a new line")
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 file.close()
#
# NameError: name 'file' is not defined

# %%
# Exercise 22
with open("log.txt", "r") as file:
    log_lines = file.readlines()
print(log_lines)
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 file.close()
#
# NameError: name 'file' is not defined

# %%
# Exercise 23
    with open("report.txt",'w') as file:
        file.write("Data analysis report")
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 file.close()
#
# NameError: name 'file' is not defined

# %%
# Exercise 24
with open("log.txt",'r') as file:
    content = file.read()
    updated_content = content.replace("error", "issue")
        with open("log.txt", "w") as file:
         file.write(updated_content)   
file.close()

# %%
# Exercise 25
with open("document.txt", "r") as file:
    text = file.read()
word_count = len(text.split())
print("Number of words:", word_count)
file.close()

# %%
# Exercise 26
with open("essay.txt",'r') as file:
    content = file.read()
    read_lines= content.splitlines()
    read_words= content.split()
    read_characters= len(content)
    print("Number of Lines:", len(lines))
    print("Number of Words:", len(words))
    print("Number of characters:", read_characters)
    file.close()

# %%
# Exercise 27
with open("source.txt",'r')as source_file: 
    copy=source_file.read()
    with open("destination.txt",'w')as destination_file: 
        destination_file.write(copy)
        file.close()

# %%
# Exercise 28
def count_lines(filename):
    with open(filename, "r") as file:
        return len(file.readlines())
        file.close()

# %%
# Exercise 29
with open("article.txt", "r") as file:
    words = file.read().split()
   long_words = [word for word in words if len(word) > 5]
print(long_words) 
file.close()

# %%
# Exercise 30
with open('notes.txt','r')as file: 
    conte=file.read()
    conv=conte.upper()
    with open('uppercase_notes.txt','w')as file:
        file.write(conv)
        file.close()

# %%
# Exercise 31 
with open("file.txt", "r") as f:
    lines = f.readlines()

with open("file.txt", "w") as f:
    for line in lines:
        if line.strip():
            f.write(line)
    file.close()

# %%
# Exercise 32
file = open("config.txt", "r+")

file.close()

# %%
# Exercise 33
def print_longest_line(filename):
    with open(filename, "r") as file:
        longest = max(file.readlines(), key=len)
    print(longest.strip())

# %%
# Exercise 34
from collections import Counter

with open("message.txt", "r") as file:
    text = file.read().replace(" ", "").lower()

letters = [char for char in text if char.isalpha()]
freq = Counter(letters)
print(freq)

# %%
# Exercise 35
with open("file.txt", "r") as file:
    content = file.read().replace(" ", "")

print("Total characters (no spaces):", len(content))

# %%
# Exercise 36
def is_empty(filename):
    return os.stat(filename).st_size == 0

print(is_empty("check.txt"))

# %%
# Exercise 37
import string

def remove_punctuation(filename):
    with open(filename, "r") as file:
        text = file.read()
    no_punct = text.translate(str.maketrans('', '', string.punctuation))
    return no_punct

print(remove_punctuation("example.txt"))

# %%
# Exercise 38
def write_lines(filename, lines):
    with open(filename, "w") as file:
        for line in lines:
            file.write(line + "\n")

write_lines("output.txt", ["Hello", "World", "Python is great"])

# %%
# Exercise 39
count = 0
with open("textfile.txt", "r") as file:
    for line in file:
        if line.startswith("A"):
            count += 1
print("Lines starting with A:", count)

# %%
# Exercise 40
def reverse_and_write(text):
    with open("output.txt", "w") as file:
        file.write(text[::-1])

reverse_and_write("Hello Python!")

# %%
# Exercise 41
with open("file.txt", "r") as file:
    for line in file:
        if "Python" in line:
            print(line.strip())

# %%
# Exercise 42
with open("file.txt", "r") as file:
    content = file.read()

cleaned = ''.join(char for char in content if not char.isdigit())

with open("file.txt", "w") as file:
    file.write(cleaned)

# %%
# Exercise 44
with open("file.txt", "r") as file:
    for line in file:
        if len(line.split()) == 5:
            print(line.strip())

# %%
# Exercise 45
with open("file.txt", "r") as file:
    lines = file.readlines()

if lines:
    print("First:", lines[0].strip())
    print("Last:", lines[-1].strip())

# %%
# Exercise 46
print("Writable" if open("students.txt", "a").writable() else "Not writable")

# %%
# Exercise 47
def count_unique_words(filename):
    with open(filename, "r") as file:
        words = file.read().lower().split()
    return len(set(words))

print(count_unique_words("file.txt"))

# %%
# Exercise 48
with open("file.txt", "r") as file:
    lines = file.readlines()

for line in reversed(lines):
    print(line.strip())

# %%
# Exercise 49
def most_common_letter(filename):
    with open(filename, "r") as file:
        text = file.read().lower()
    letters = [c for c in text if c.isalpha()]
    return Counter(letters).most_common(1)[0][0]

print(most_common_letter("file.txt"))

# %%
# Exercise 50
with open("file.txt", "r") as file:
    content = file.read()

content = content.replace("Python", "Java")

with open("file.txt", "w") as file:
    file.write(content)
